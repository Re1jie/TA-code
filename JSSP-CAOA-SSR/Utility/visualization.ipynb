# %%
import plotly.express as px
import pandas as pd
import re

# %%
DATA_INPUT = '/home/re1jie/TA-code/JSSP-CAOA-SSR/Data/raw_data.csv'
df = pd.read_csv(DATA_INPUT)
df.head()
# Out:
#   NAMA_KAPAL  VOYAGE PELABUHAN ETA_HARI ETA_TANGGAL ETA_JAM ETD_HARI  \
# 0     KM.AWU  1.2025     Kumai     Rabu    8-Jan-25   04:00     Rabu
# 1     KM.AWU  1.2025  Surabaya    Kamis    9-Jan-25   17:00    Kamis
# 2     KM.AWU  1.2025     Benoa    Sabtu   11-Jan-25   03:00    Sabtu
# 3     KM.AWU  1.2025      Bima   Minggu   12-Jan-25   06:00   Minggu
# 4     KM.AWU  1.2025  Waingapu   Minggu   12-Jan-25   22:00    Senin
#
#   ETD_TANGGAL ETD_JAM
# 0    8-Jan-25   14:00
# 1    9-Jan-25   23:59
# 2   11-Jan-25   09:00
# 3   12-Jan-25   08:00
# 4   13-Jan-25   01:00

# %% [markdown]
# ## Normalisasi datetime

# %%
# Mapping helper
bulan_map = {
    "Jan": "Jan",
    "Feb": "Feb",
    "Mar": "Mar",
    "Apr": "Apr",
    "Mei": "May",
    "Jun": "Jun",
    "Jul": "Jul",
    "Agu": "Aug",
    "Sep": "Sep",
    "Okt": "Oct",
    "Nov": "Nov",
    "Des": "Dec"
}

pattern = re.compile("|".join(bulan_map.keys()))

def normalize_date(date_str):
    if pd.isna(date_str):
        return None

    date_str = str(date_str)

    return pattern.sub(lambda x: bulan_map[x.group()], date_str)

df["ETA_TANGGAL"] = df["ETA_TANGGAL"].apply(normalize_date)
df["ETD_TANGGAL"] = df["ETD_TANGGAL"].apply(normalize_date)

# Build datetime ETA
df["ETA"] = pd.to_datetime(
    df["ETA_TANGGAL"] + " " + df["ETA_JAM"],
    format="%d-%b-%y %H:%M",
    errors="coerce"
)

df["ETD"] = pd.to_datetime(
    df["ETD_TANGGAL"] + " " + df["ETD_JAM"],
    format="%d-%b-%y %H:%M",
    errors="coerce"
)

df = df.sort_values(
    ["NAMA_KAPAL", "ETA"]
)

df["ETD"] = df["ETD"].fillna(
    df.groupby("NAMA_KAPAL")["ETA"].shift(-1)
)

invalid = df[df["ETD"] < df["ETA"]]
print("Invalid rows:", len(invalid))

df.head()
# Out:
# Invalid rows: 0
#         NAMA_KAPAL  VOYAGE PELABUHAN ETA_HARI ETA_TANGGAL ETA_JAM ETD_HARI  \
# 3558  KFC.JETLINER  1.2025   Kendari    Sabtu   28-Dec-24   22:00   Minggu
# 3559  KFC.JETLINER  1.2025     Wanci   Minggu   29-Dec-24   20:00   Minggu
# 3560  KFC.JETLINER  1.2025   Kendari    Senin   30-Dec-24   11:00    Senin
# 3561  KFC.JETLINER  1.2025     Wanci   Selasa   31-Dec-24   06:00   Selasa
# 3562  KFC.JETLINER  1.2025   Kendari   Selasa   31-Dec-24   21:00   Selasa
#
#      ETD_TANGGAL ETD_JAM                 ETA                 ETD
# 3558   29-Dec-24   07:00 2024-12-28 22:00:00 2024-12-29 07:00:00
# 3559   29-Dec-24   22:00 2024-12-29 20:00:00 2024-12-29 22:00:00
# 3560   30-Dec-24   17:00 2024-12-30 11:00:00 2024-12-30 17:00:00
# 3561   31-Dec-24   08:00 2024-12-31 06:00:00 2024-12-31 08:00:00
# 3562   31-Dec-24   23:00 2024-12-31 21:00:00 2024-12-31 23:00:00

# %%
print(df[["NAMA_KAPAL","VOYAGE","PELABUHAN","ETA","ETD"]].head(20))
# Out:
#         NAMA_KAPAL  VOYAGE PELABUHAN                 ETA                 ETD
# 3558  KFC.JETLINER  1.2025   Kendari 2024-12-28 22:00:00 2024-12-29 07:00:00
# 3559  KFC.JETLINER  1.2025     Wanci 2024-12-29 20:00:00 2024-12-29 22:00:00
# 3560  KFC.JETLINER  1.2025   Kendari 2024-12-30 11:00:00 2024-12-30 17:00:00
# 3561  KFC.JETLINER  1.2025     Wanci 2024-12-31 06:00:00 2024-12-31 08:00:00
# 3562  KFC.JETLINER  1.2025   Kendari 2024-12-31 21:00:00 2024-12-31 23:00:00
# 3563  KFC.JETLINER  1.2025      Raha 2025-01-01 07:00:00 2025-01-01 08:00:00
# 3564  KFC.JETLINER  1.2025   Kendari 2025-01-01 16:00:00 2025-01-01 18:00:00
# 3565  KFC.JETLINER  1.2025     Wanci 2025-01-02 07:00:00 2025-01-02 09:00:00
# 3566  KFC.JETLINER  1.2025   Kendari 2025-01-02 22:00:00 2025-01-03 17:00:00
# 3567  KFC.JETLINER  1.2025     Wanci 2025-01-04 06:00:00 2025-01-04 08:00:00
# 3568  KFC.JETLINER  1.2025   Kendari 2025-01-04 21:00:00 2025-01-04 21:00:00
# 3569  KFC.JETLINER  2.2025   Kendari 2025-01-04 21:00:00 2025-01-05 07:00:00
# 3570  KFC.JETLINER  2.2025     Wanci 2025-01-05 20:00:00 2025-01-05 22:00:00
# 3571  KFC.JETLINER  2.2025   Kendari 2025-01-06 11:00:00 2025-01-06 17:00:00
# 3572  KFC.JETLINER  2.2025     Wanci 2025-01-07 06:00:00 2025-01-07 08:00:00
# 3573  KFC.JETLINER  2.2025   Kendari 2025-01-07 21:00:00 2025-01-07 23:00:00
# 3574  KFC.JETLINER  2.2025      Raha 2025-01-08 07:00:00 2025-01-08 08:00:00
# 3575  KFC.JETLINER  2.2025   Kendari 2025-01-08 16:00:00 2025-01-08 18:00:00
# 3576  KFC.JETLINER  2.2025     Wanci 2025-01-09 07:00:00 2025-01-09 09:00:00
# 3577  KFC.JETLINER  2.2025   Kendari 2025-01-09 22:00:00 2025-01-10 17:00:00

# %% [markdown]
# ## Visualisasi

# %%
df = df.sort_values(["NAMA_KAPAL", "ETA"]).reset_index(drop=True)

df["NEXT_ETA"] = df.groupby("NAMA_KAPAL")["ETA"].shift(-1)

sandar = df.copy()

sandar["START"] = sandar["ETA"]
sandar["END"] = sandar["ETD"]
sandar["STATUS"] = "Sandar"

layar = df.copy()

layar["START"] = layar["ETD"]
layar["END"] = layar["NEXT_ETA"]
layar["STATUS"] = "Layar"

layar = layar.dropna(subset=["START", "END"])

timeline = pd.concat([sandar, layar], ignore_index=True)

timeline = timeline[timeline["END"] > timeline["START"]]

# %%
fig = px.timeline(
    timeline,
    x_start="START",
    x_end="END",
    y="NAMA_KAPAL",
    color="STATUS",            # Sandar vs Layar
    hover_data=[
        "VOYAGE",
        "PELABUHAN",
        "ETA",
        "ETD"
    ]
)

fig.update_yaxes(autorange="reversed")

fig.update_layout(
    title="Timeline Operasional Kapal (Sandar vs Layar)",
    xaxis_title="Waktu",
    yaxis_title="Kapal",
    hovermode="closest"
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 fig = px.timeline(
#       2     timeline,
#       3     x_start="START",
#       4     x_end="END",
#       5     y="NAMA_KAPAL",
#       6     color="STATUS",            # Sandar vs Layar
#       7     hover_data=[
#       8         "VOYAGE",
#       9         "PELAPUHAN",
#      10         "ETA",
#      11         "ETD"
#      12     ]
#      13 )
#      15 fig.update_yaxes(autorange="reversed")
#      17 fig.update_layout(
#      18     title="Timeline Operasional Kapal (Sandar vs Layar)",
#      19     xaxis_title="Waktu",
#      20     yaxis_title="Kapal",
#      21     hovermode="closest"
#      22 )
#
# File ~/TA-code/.env-ta/lib/python3.12/site-packages/plotly/express/_chart_types.py:432, in timeline(data_frame, x_start, x_end, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, range_x, range_y, title, subtitle, template, width, height)
#     392 def timeline(
#     393     data_frame=None,
#     394     x_start=None,
#    (...)    426     height=None,
#     427 ) -> go.Figure:
#     428     """
#     429     In a timeline plot, each row of `data_frame` is represented as a rectangular
#     430     mark on an x axis of type `date`, spanning from `x_start` to `x_end`.
#     431     """
# --> 432     return make_figure(
#     433         args=locals(),
#     434         constructor="timeline",
#     435         trace_patch=dict(textposition="auto", orientation="h"),
#     436         layout_patch=dict(barmode="overlay"),
#     437     )
#
# File ~/TA-code/.env-ta/lib/python3.12/site-packages/plotly/express/_core.py:2511, in make_figure(args, constructor, trace_patch, layout_patch)
#    2508 layout_patch = layout_patch or {}
#    2509 apply_default_cascade(args, constructor=constructor)
# -> 2511 args = build_dataframe(args, constructor)
#    2512 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2513     args = process_dataframe_hierarchy(args)
#
# File ~/TA-code/.env-ta/lib/python3.12/site-packages/plotly/express/_core.py:1757, in build_dataframe(args, constructor)
#    1754     args["color"] = None
#    1755 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1757 df_output, wide_id_vars = process_args_into_dataframe(
#    1758     args,
#    1759     wide_mode,
#    1760     var_name,
#    1761     value_name,
#    1762     is_pd_like,
#    1763     native_namespace,
#    1764 )
#    1765 df_output: nw.DataFrame
#    1766 # now that `df_output` exists and `args` contains only references, we complete
#    1767 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1768 # df_output
#
# File ~/TA-code/.env-ta/lib/python3.12/site-packages/plotly/express/_core.py:1358, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1356         if argument == "index":
#    1357             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1358         raise ValueError(err_msg)
#    1359 elif length and (actual_len := len(df_input)) != length:
#    1360     raise ValueError(
#    1361         "All arguments should have the same length. "
#    1362         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)   1369         )
#    1370     )
#
# ValueError: Value of 'hover_data_1' is not the name of a column in 'data_frame'. Expected one of ['NAMA_KAPAL', 'VOYAGE', 'PELABUHAN', 'ETA_HARI', 'ETA_TANGGAL', 'ETA_JAM', 'ETD_HARI', 'ETD_TANGGAL', 'ETD_JAM', 'ETA', 'ETD', 'NEXT_ETA', 'START', 'END', 'STATUS'] but received: PELAPUHAN
