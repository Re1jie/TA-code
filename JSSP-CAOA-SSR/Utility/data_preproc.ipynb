# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pathlib import Path
import re
import glob
import os

# %% [markdown]
# # Voyage Kapal

# %%
VOYAGE_DATA = '../Data/voyage_data.csv'

# %% [markdown]
# ## List pelabuhan unik

# %%
def get_unique_ports(file_path):
    print(f"Membaca file: {file_path}")

    df = pd.read_csv(file_path)
    raw_ports = df['PELABUHAN'].astype(str).str.strip()
    unique_ports = raw_ports.unique()
    unique_ports = sorted(raw_ports.unique())
    
    count = len(unique_ports)

    print(f"Ditemukan {count} pelabuhan unik.")
    print("\nDaftar Pelabuhan:")
    for i, port in enumerate(unique_ports):
        print(f"{i+1}. {port}")
        
    return unique_ports, count

ports_list, total_ports = get_unique_ports(VOYAGE_DATA)
# Out:
# Membaca file: ../Data/voyage_data.csv
# Ditemukan 76 pelabuhan unik.
#
# Daftar Pelabuhan:
# 1. AGATS
# 2. AMBON
# 3. AWERANGE
# 4. BACAN
# 5. BALIKPAPAN
# 6. BANDA
# 7. BANGGAI
# 8. BATAM
# 9. BATULICIN
# 10. BAUBAU
# 11. BELAWAN
# 12. BENOA
# 13. BIAK
# 14. BIMA
# 15. BITUNG
# 16. BLINYU
# 17. BONTANG
# 18. CILEGON
# 19. CIREBON
# 20. DOBO
# 21. ENDE
# 22. FAKFAK
# 23. GESER
# 24. GORONTALO
# 25. JAILOLO
# 26. JAYAPURA
# 27. KAIMANA
# 28. KALABAHI
# 29. KARIMUN JAWA
# 30. KENDARI
# 31. KIJANG
# 32. KUMAI
# 33. KUPANG
# 34. LABUAN BAJO
# 35. LARANTUKA
# 36. LEMBAR
# 37. LETUNG
# 38. LEWOLEBA
# 39. LUWUK
# 40. MAKASSAR
# 41. MANOKWARI
# 42. MAUMERE
# 43. MERAUKE
# 44. MIDAI
# 45. NABIRE
# 46. NAMLEA
# 47. NAMROLE
# 48. NATUNA
# 49. NUNUKAN
# 50. PANTOLOAN
# 51. PAREPARE
# 52. PONTIANAK
# 53. RAHA
# 54. ROTE
# 55. SAMPIT
# 56. SANANA
# 57. SAUMLAKI
# 58. SEMARANG
# 59. SERASAN
# 60. SERUI
# 61. SORONG
# 62. SURABAYA
# 63. TANJUNG BALAI KARIMUN
# 64. TANJUNG PANDAN
# 65. TANJUNG PRIOK
# ...

# %%
def jssp_transform(file_path, output_path):
    # 1. Load & Parse
    print(f"Membaca file dari: {file_path}")
    df = pd.read_csv(file_path, dtype={'VOYAGE': str})
    
    # Helper Parsing
    ID_TO_EN = {'Des': 'Dec', 'Mei': 'May', 'Agt': 'Aug', 'Agu': 'Aug', 
                'Okt': 'Oct', 'Juli': 'Jul', 'Juni': 'Jun'}

    def parse_dt(d, t):
        if pd.isna(d) or pd.isna(t): return pd.NaT
        d_str = str(d).strip()
        for id_m, en_m in ID_TO_EN.items():
            if id_m in d_str: d_str = d_str.replace(id_m, en_m)
        try:
            return datetime.strptime(f"{d_str} {str(t).strip()}", "%d-%b-%y %H:%M")
        except:
            return pd.NaT

    df['ETA_FULL'] = df.apply(lambda x: parse_dt(x['ETA_TANGGAL'], x['ETA_JAM']), axis=1)
    df['ETD_FULL'] = df.apply(lambda x: parse_dt(x['ETD_TANGGAL'], x['ETD_JAM']), axis=1)
    df = df.dropna(subset=['ETA_FULL']).sort_values('ETA_FULL')

    # 2. Mappings
    unique_ports = sorted(df['PELABUHAN'].unique())
    port_map = {p: i+1 for i, p in enumerate(unique_ports)}
    df['Machine_ID'] = df['PELABUHAN'].map(port_map)
    
    df['JOB_KEY'] = df['NAMA_KAPAL'] + "_" + df['VOYAGE']
    unique_jobs = df['JOB_KEY'].unique()
    job_map = {k: i+1 for i, k in enumerate(unique_jobs)}
    
    # 3. Time Reference (t=0)
    # global_start = df['ETA_FULL'].min()
    global_start = datetime(2025, 1, 1, 0, 0)
    
    jssp_rows = []
    
    # GROUPING JOB
    for job_key, group in df.groupby('JOB_KEY'):
        group = group.sort_values('ETA_FULL')
        records = group.to_dict('records') 
        seq = 1
        
        # [MODIFIKASI UTAMA]
        # Kita hanya looping sampai len(records) - 1.
        # Baris TERAKHIR (Destinasi Akhir Voyage) tidak dianggap sebagai operasi JSSP,
        # melainkan hanya sebagai acuan ETA untuk menghitung Travel Time operasi sebelumnya.
        
        for i in range(len(records) - 1):
            row = records[i]
            next_row = records[i + 1] # Aman diakses karena loop cuma sampai len-1
            
            # --- 1. Arrival Time (Ready Time) ---
            arr_rel = (row['ETA_FULL'] - global_start).total_seconds() / 3600.0
            
            # --- 2. Processing Time & Due Date ---
            if pd.notna(row['ETD_FULL']):
                proc_time = (row['ETD_FULL'] - row['ETA_FULL']).total_seconds() / 3600.0
                due_date_rel = (row['ETD_FULL'] - global_start).total_seconds() / 3600.0
            else:
                # Fallback jika ETD kosong di tengah voyage (jarang terjadi di data bersih)
                proc_time = 0.0
                due_date_rel = arr_rel 
            
            # --- 3. Travel Time Logic ---
            # Sekarang logic ini PASTI jalan dan PASTI punya next_row
            travel_time = 0.0
            
            if pd.notna(row['ETD_FULL']) and pd.notna(next_row['ETA_FULL']):
                travel_delta = next_row['ETA_FULL'] - row['ETD_FULL']
                travel_time = travel_delta.total_seconds() / 3600.0
                # Cegah nilai negatif jika jadwal berantakan
                travel_time = max(0.0, travel_time)
            
            jssp_rows.append({
                'Job_ID': job_map[job_key],
                'Job_Label': job_key,
                'Operation_Seq': seq,
                'Machine_ID': row['Machine_ID'],
                'Port_Label': row['PELABUHAN'],
                'Travel_Time': round(travel_time, 2),
                'Arrival_Time': round(arr_rel, 2),
                'Proc_Time': max(0.0, round(proc_time, 2)),
                'Due_Date': round(due_date_rel, 2),
            })
            seq += 1
            
            # Baris terakhir (Destinasi) otomatis ter-skip oleh range loop,
            # tapi datanya (ETA) sudah terpakai di perhitungan 'travel_time' iterasi terakhir.
    
    final_df = pd.DataFrame(jssp_rows)  
    final_df = final_df.sort_values(by=['Job_ID', 'Operation_Seq'])
    final_df.to_csv(output_path, index=False)

    print(f"Data tersimpan di {output_path}")

OUTPUT = '../Data/transformed_data.csv'
jssp_transform(VOYAGE_DATA, OUTPUT)
# Out:
# Membaca file dari: ../Data/voyage_data.csv
# Data tersimpan di ../Data/transformed_data.csv

# %%
df = pd.read_csv(OUTPUT)
df.describe()
# Out:
#             Job_ID  Operation_Seq   Machine_ID  Travel_Time  Arrival_Time  \
# count  8606.000000    8606.000000  8606.000000  8606.000000   8606.000000
# mean    293.233674       8.767720    37.586103    17.735615   4408.690797
# std     169.379148       5.550661    22.415043    10.006417   2465.257043
# min       1.000000       1.000000     1.000000     0.000000     13.000000
# 25%     146.000000       4.000000    15.000000    10.000000   2276.000000
# 50%     294.000000       8.000000    40.000000    16.000000   4384.000000
# 75%     442.000000      13.000000    60.000000    24.020000   6575.250000
# max     583.000000      29.000000    76.000000   137.000000   8717.000000
#
#          Proc_Time     Due_Date
# count  8606.000000  8606.000000
# mean      6.747883  4415.438680
# std      46.043492  2464.960482
# min       0.000000    26.000000
# 25%       2.000000  2278.000000
# 50%       2.000000  4392.490000
# 75%       4.000000  6591.750000
# max    1665.000000  8719.000000

# %% [markdown]
# # Kepelabuhanan

# %% [markdown]
# ## Pasang Surut Pelabuhan

# %%
FOLDER_DATA_TIDAL = '../Data/Tidal/*.csv'
TIDAL_DATA = glob.glob(FOLDER_DATA_TIDAL)

# %%
df = pd.concat(
    (pd.read_csv(file) for file in TIDAL_DATA),
    ignore_index=True
)

df.to_csv('../Data/tidal_data.csv', index=False)
TIDAL_DATA = '../Data/tidal_data.csv'

# %% [markdown]
# ## Peraturan Pelabuhan

# %%
PORT_SPEC_DATA = '../Data/port_data.csv'
PORT_RULES_DATA = '../Data/tidal_rules.csv'

# %%
df = pd.read_csv(PORT_SPEC_DATA)
df.head(10)
# Out:
#   Nama_Pelabuhan Wilayah  Max_Ship_Type  Total_Berths  isHub
# 0        BELAWAN   Barat           2000             1  False
# 1          BATAM   Barat           2000             1  False
# 2       MAKASSAR  Tengah           2000             2   True
# 3         BAUBAU  Tengah           2000             2  False
# 4       SURABAYA   Barat           2000             1   True
# 5       PAREPARE  Tengah           2000             1  False
# 6  TANJUNG PRIOK   Barat           2000             2   True
# 7          AMBON  Tengah           2000             2   True
# 8        TERNATE   Timur           2000             1  False
# 9      MANOKWARI   Timur           2000             1  False

# %%
df = pd.read_csv(PORT_RULES_DATA )
df.head(10)
# Out:
#    port_name  min_elevation  buffer_time      ship_name
# 0     SAMPIT            2.4            4       KM.LAWIT
# 1      KUMAI            0.8            2       KM.LAWIT
# 2      KUMAI            0.8            2    KM.KELIMUTU
# 3      KUMAI            0.8            2         KM.AWU
# 4  PONTIANAK            1.1            2    KM.KELIMUTU
# 5  PONTIANAK            1.1            2   KM.BUKITRAYA
# 6    MERAUKE            4.0            2  KM.TATAMAILAU
# 7    MERAUKE            4.0            2     KM.SIRIMAU
# 8    MERAUKE            4.0            2      KM.LEUSER
# 9      AGATS            1.5            2  KM.TATAMAILAU

# %% [markdown]
# # Validasi

# %%
import pandas as pd
import numpy as np
import math
from datetime import timedelta

print("======================================================")
print(" MULAI PIPELINE VALIDASI PASANG SURUT (MANUVER ONLY)")
print("======================================================\n")

# 1. LOAD DATA
print("[DEBUG FASE 1] Memuat Data...")
tidal_data = pd.read_csv(TIDAL_DATA)
transformed_data = pd.read_csv(OUTPUT)
tidal_rules = pd.read_csv(PORT_RULES_DATA)

print(f" -> tidal_data dimuat: {len(tidal_data)} baris.")
print(f" -> transformed_data dimuat: {len(transformed_data)} baris jadwal.")
print(f" -> tidal_rules dimuat: {len(tidal_rules)} aturan.\n")


# 2. PIPELINE KONVERSI WAKTU (Fase 1)
print("[DEBUG FASE 2] Memproses Konversi Waktu (t=0 pada 2025-01-01 00:00:00)...")
def parse_timestamp(ts):
    if " 24:00:00" in ts:
        date_part = ts.replace(" 24:00:00", " 00:00:00")
        return pd.to_datetime(date_part) + timedelta(days=1)
    return pd.to_datetime(ts)

tidal_data['timestamp'] = tidal_data['timestamp'].apply(parse_timestamp)
base_time = pd.to_datetime('2025-01-01 00:00:00')
tidal_data['t_hour'] = ((tidal_data['timestamp'] - base_time).dt.total_seconds() / 3600).astype(int)

tidal_dict = tidal_data.set_index(['port_name', 't_hour'])['tidal_elevation'].to_dict()
print(f" -> Dictionary tidal_dict berhasil dibuat dengan {len(tidal_dict)} entri.\n")


# 3. PIPELINE VALIDASI JSSP (Fase 2)
print("[DEBUG FASE 3] Mempersiapkan Data JSSP & Penggabungan Rule...")
transformed_data['ship_name'] = transformed_data['Job_Label'].apply(lambda x: x.split('_')[0])

validation_df = pd.merge(
    transformed_data, 
    tidal_rules, 
    left_on=['Port_Label', 'ship_name'], 
    right_on=['port_name', 'ship_name'], 
    how='left'
)

jobs_to_check = validation_df.dropna(subset=['min_elevation']).copy()
print(f"\n -> Terdapat {len(jobs_to_check)} operasi jadwal yang TERIKAT batasan pasang surut.")

violations = []
print("\n[DEBUG FASE 4] Memulai Pengecekan Elevasi Saat Manuver Kedatangan & Keberangkatan...")

debug_counter = 0 

for idx, row in jobs_to_check.iterrows():
    port = row['Port_Label']
    ship = row['ship_name']
    job_label = row['Job_Label']
    arr_time = row['Arrival_Time']
    proc_time = row['Proc_Time']
    min_elev = row['min_elevation']
    buffer_time = row['buffer_time'] if not pd.isna(row['buffer_time']) else 0
    
    # -------------------------------------------------------------
    # LOGIKA BARU: Pemisahan Window Manuver (Mengabaikan Proc_Time)
    # -------------------------------------------------------------
    
    # Window Kedatangan: [Arr - Buffer] s/d [Arr]
    arr_start_hour = math.floor(arr_time - buffer_time)
    arr_end_hour = math.ceil(arr_time)
    
    # Waktu Selesai (Departure Base Time)
    dep_time = arr_time + proc_time
    
    # Window Keberangkatan: [Dep] s/d [Dep + Buffer]
    dep_start_hour = math.floor(dep_time)
    dep_end_hour = math.ceil(dep_time + buffer_time)
    
    violation_details = []
    
    if debug_counter < 3:
        arr_start_actual = base_time + timedelta(hours=arr_start_hour)
        arr_end_actual = base_time + timedelta(hours=arr_end_hour)
        dep_start_actual = base_time + timedelta(hours=dep_start_hour)
        dep_end_actual = base_time + timedelta(hours=dep_end_hour)
        
        print(f"\n   [Cek Manuver] Job: {job_label} di {port} | Min Elev: {min_elev}m")
        print(f"       -> Masuk (Arrival): {arr_start_actual.strftime('%Y-%m-%d %H:%M:%S')} s/d {arr_end_actual.strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"       -> Keluar (Depart): {dep_start_actual.strftime('%Y-%m-%d %H:%M:%S')} s/d {dep_end_actual.strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"       *(Mengabaikan durasi sandar selama {proc_time} jam)*")
    
    # 1. Cek Elevasi Window Kedatangan
    for t in range(arr_start_hour, arr_end_hour + 1):
        elev = tidal_dict.get((port, t), None)
        if elev is not None and elev < min_elev:
            actual_time = base_time + timedelta(hours=t)
            waktu_str = actual_time.strftime('%Y-%m-%d %H:%M:%S')
            violation_details.append(f"[MASUK: {waktu_str} -> Elev: {elev}m]")

    # 2. Cek Elevasi Window Keberangkatan
    for t in range(dep_start_hour, dep_end_hour + 1):
        elev = tidal_dict.get((port, t), None)
        if elev is not None and elev < min_elev:
            actual_time = base_time + timedelta(hours=t)
            waktu_str = actual_time.strftime('%Y-%m-%d %H:%M:%S')
            violation_details.append(f"[KELUAR: {waktu_str} -> Elev: {elev}m]")
            
    if violation_details:
        if debug_counter < 3:
            print("       >>> PELANGGARAN DETECTED:")
            for detail in violation_details:
                print(f"           - {detail}")
                
        violations.append({
            'Job_ID': row['Job_ID'],
            'Job_Label': job_label,
            'Operation_Seq': row['Operation_Seq'],
            'Port': port,
            'Arrival_Time (t)': arr_time,
            'Departure_Time (t)': dep_time,
            'Proc_Time (h)': proc_time,
            'Required_Min_Elevation': min_elev,
            'Violations_Found (Fase: Waktu Aktual & Elevasi)': " | ".join(violation_details)
        })
    elif debug_counter < 3:
        print("       >>> AMAN.")
        
    debug_counter += 1

print("\n[DEBUG FASE 5] Kompilasi Hasil Akhir...")
# 4. REPORTING
violations_df = pd.DataFrame(violations)
if not violations_df.empty:
    violations_df.to_csv('validation_results_waktu_aktual.csv', index=False)
    print("======================================================")
    print(f" FATAL ERROR PADA MANUVER KAPAL!")
    print(f" Ditemukan {len(violations_df)} operasi jadwal di mana elevasi air tidak aman saat kapal MASUK atau KELUAR pelabuhan.")
    print(" File 'validation_results_waktu_aktual.csv' telah dibuat.")
    print("======================================================")
else:
    print("======================================================")
    print(" SUCCESS: Semua jadwal manuver masuk/keluar memenuhi kriteria elevasi minimum.")
    print("======================================================")
# Out:
# ...
#  MULAI PIPELINE VALIDASI PASANG SURUT (MANUVER ONLY)
# ...
#
# [DEBUG FASE 1] Memuat Data...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[66], line 12
#      10 # 1. LOAD DATA
#      11 print("[DEBUG FASE 1] Memuat Data...")
# ---> 12 tidal_data = pd.read_csv('tidal_data.csv')
#      13 transformed_data = pd.read_csv('transformed_data.csv')
#      14 tidal_rules = pd.read_csv('tidal_rules.csv')
#
# ...
